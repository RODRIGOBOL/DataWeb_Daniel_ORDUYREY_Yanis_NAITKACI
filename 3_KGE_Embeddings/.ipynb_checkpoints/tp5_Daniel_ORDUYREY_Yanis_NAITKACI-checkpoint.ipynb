# %% [markdown]
# # Lab Session: Knowledge reasoning with rule and Knowledge Graph Embedding (KGE)

# %% [markdown]
# ## Part 1 - Knowledge reasoning with SWRL

# %% [markdown]
# ## Part 2 - Knowledge Graph Embedding

# %% [markdown]
# ## 1 — Data Preparation

# %% [markdown]
# ### 1.1 Input

# %% [markdown]
# ### 1.2 Cleaning for Embedding

# %% [markdown]
# ### 1.3 Train / Validation / Test Split

# %% [markdown]
# ## 2 — Embedding Models

# %% [markdown]
# ## 3 — Training Configuration

# %% [markdown]
# ## 4 — Evaluation Task: Link Prediction

# %% [markdown]
# ## 5 — Experiments to Conduct

# %% [markdown]
# ### 5.1 Model Comparison

# %% [markdown]
# ### 5.2 KB Size Sensitivity

# %% [markdown]
# ## 6 — Embedding Analysis

# %% [markdown]
# ### 6.1 Nearest Neighbors

# %% [markdown]
# ### 6.2 Clustering analysis

# %% [markdown]
# ### 6.3 Relation Behavior

# %% [markdown]
# ## 7 — Critical Reflection

# %% [markdown]
# ## 8 - Comparison between rule-based and embedding based reasoning
